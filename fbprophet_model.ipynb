# %%
import pandas as pd # 데이터 전처리
import numpy as np # 데이터 전처리
import matplotlib.pyplot as plt # 데이터 시각화

import warnings
from tqdm import tqdm
from datetime import datetime, timedelta # 시간 데이터 처리

from statsmodels.tsa.arima_model import ARIMA # ARIMA 모델
from fbprophet import Prophet

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
def fill_nan(df):
    for col in df.columns[1:]:
        start_dt = df.loc[df.loc[:, col].isnull() == False].index[0]
        from_dt = start_dt
        from_val = df.loc[start_dt, col]

        for dt, val in df.loc[start_dt:, col].items():
            if not pd.isna(val):
                # processing
                length = len(df.loc[from_dt: dt, col]) - 1
                if length != 0:
                    for i in df.loc[from_dt: dt, col].index:
                        df.loc[i, col] = from_val / length

                from_dt = dt
                from_val = val
    return df


def to_panel_format(df):
    place_id=[]; time=[] ; target=[] # 빈 리스트를 생성합니다.
    
    df['Time'] = pd.to_datetime(df['Time']) 
    df = df.set_index('Time')
    
    for i in df.columns:
        for j in range(len(df)):
            place_id.append(i) # place_id에 미터 ID를 정리합니다.
            time.append(df.index[j]) # time에 시간대를 정리합니다.
            target.append(df[i].iloc[j]) # target에 전력량을 정리합니다.

    ret = pd.DataFrame({'place_id':place_id,'time':time,'target':target})
    ret = ret.dropna() # 결측치를 제거합니다.
    ret = ret.set_index('time') # time을 인덱스로 저장합니다.
    return ret


def get_optimal_params(y):
    param_dict = {}
    
    for param in pdq:
        try:
            model = ARIMA(y, order=param)
            results_ARIMA = model.fit(disp=-1)
            param_dict[results_ARIMA.aic] = param
        except:
            continue

    min_aic = min(param_dict.keys())
    optimal_params = param_dict[min_aic]
    return optimal_params

def prediction(df):
    p = d = q = range(0, 2)
    pdq = list(itertools.product(p, d, q))

    ret = {}
    sub = pd.DataFrame() # a라는 데이터프레임에 예측값을 정리합니다.

    for key in df['place_id'].unique(): # 미터ID 200개의 리스트를 unique()함수를 통해 추출합니다.
        temp = df.loc[df['place_id']==key] # 미터ID 하나를 할당합니다.
        temp_1h = temp.resample('1h').sum() # 1시간 단위로 정리합니다.
        temp_1day = temp.resample('D').sum() # 1일 단위로 정리합니다.

        # 시간별 예측
        model = ARIMA(temp_1h['target'], order=get_optimal_params(temp_1h['target'])) # AIC를 최소화하는 최적의 파라미터로 모델링합니다.
        results_ARIMA = model.fit(disp=-1)
        fcst = results_ARIMA.forecast(24) # 24시간을 예측합니다.
        for i in range(24):
            sub['X2018_7_1_'+str(i+1)+'h'] = [fcst[0][i]] # column명을 submission 형태에 맞게 지정합니다.

        # 일별 예측
        model = ARIMA(temp_1day['target'], order=get_optimal_params(temp_1day['target'])) # AIC를 최소화하는 최적의 파라미터로 모델링합니다.
        results_ARIMA = model.fit(disp=-1)
        fcst = results_ARIMA.forecast(10) # 10일을 예측합니다.
        for i in range(10):
            sub['X2018_7_'+str(i+1)+'_d'] = [fcst[0][i]] # column명을 submission 형태에 맞게 지정합니다.

        # 월별 예측
        # 일별로 예측하여 7월 ~ 11월의 일 수에 맞게 나누어 합산합니다.
        fcst = results_ARIMA.forecast(153)
        sub['X2018_7_m'] = [np.sum(fcst[0][:31])] # 7월 
        sub['X2018_8_m'] = [np.sum(fcst[0][31:62])] # 8월
        sub['X2018_9_m'] = [np.sum(fcst[0][62:92])] # 9월
        sub['X2018_10_m'] = [np.sum(fcst[0][92:123])] # 10월
        sub['X2018_11_m'] = [np.sum(fcst[0][123:153])] # 11월
        sub['meter_id'] = key 
        ret[key] = sub[submission.columns.tolist()]
        print(key)
        
    print('---- Modeling Done ----')
    return ret

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
submission_1002 = pd.read_csv("submission_1002.csv")
submission_1002 = submission_1002.set_index('meter_id')

# %%
test = test.set_index('Time')
test.index = pd.to_datetime(test.index)

# %%
test = test['2017-08-25 00:00:00':]

# %% [markdown]
# # 1.Agregate by Time

# %%
temp = test.copy()
temp['hour'] = list(temp.reset_index()['Time'].apply(lambda x: x.hour))

# %%
for col in tqdm(test.columns):
    for t in range(24):
        data = temp.loc[temp['hour'] == t, col].copy()
        df = pd.DataFrame({
            'ds': data.index,
            'y': data.data,
        })

        ## Set model setting 
        m = Prophet(
            growth='linear', 
            changepoint_range=0.95,
            changepoint_prior_scale=0.1,
        )
        m.fit(df)

        ## Make dataframe for get a predicted value
        future = m.make_future_dataframe(periods=1, freq='T')

        ## Predict
        forecast = m.predict(future)
        
        ## Save the data
        submission.loc[col, 'X2017_7_1_' + str(t + 1) + '_h'] = forecast.loc[len(data), 'yhat']
        print(col)
        print(submission.loc[col, 'X2017_7_1_' + str(t + 1) + '_h'])
        print(submission.loc['X26', 'X2017_7_1_1_h'])
        submission
#     ## Show a graph
#     fig1 = m.plot(forecast)
#     plt.show()
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# X26
# 1.132195875499108
# 1.132195875499108
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-131-34600005d74d> in <module>
#      13             changepoint_prior_scale=0.1,
#      14         )
# ---> 15         m.fit(df)
#      16
#      17         ## Make dataframe for get a predicted value
#
# ~\Anaconda3\envs\tensor\lib\site-packages\fbprophet\forecaster.py in fit(self, df, **kwargs)
#    1129             args.update(kwargs)
#    1130             try:
# -> 1131                 params = model.optimizing(**args)
#    1132             except RuntimeError:
#    1133                 # Fall back on Newton
#
# ~\Anaconda3\envs\tensor\lib\site-packages\pystan\model.py in optimizing(self, data, seed, init, sample_file, algorithm, verbose, as_vector, **kwargs)
#     508         stan_args = pystan.misc._get_valid_stan_args(stan_args)
#     509
# --> 510         ret, sample = fit._call_sampler(stan_args)
#     511         pars = pystan.misc._par_vector2dict(sample['par'], m_pars, p_dims)
#     512         if not as_vector:
#
# stanfit4anon_model_db8febf10f23d7fa27a62fbcfd7f17b2_604436787436303341.pyx in stanfit4anon_model_db8febf10f23d7fa27a62fbcfd7f17b2_604436787436303341.StanFit4Model._call_sampler()
#
# stanfit4anon_model_db8febf10f23d7fa27a62fbcfd7f17b2_604436787436303341.pyx in stanfit4anon_model_db8febf10f23d7fa27a62fbcfd7f17b2_604436787436303341._call_sampler()
#
# stanfit4anon_model_db8febf10f23d7fa27a62fbcfd7f17b2_604436787436303341.pyx in stanfit4anon_model_db8febf10f23d7fa27a62fbcfd7f17b2_604436787436303341._dict_from_stanargs()
#
# ~\Anaconda3\envs\tensor\lib\enum.py in __call__(cls, value, names, module, qualname, type, start)
#     308         """
#     309         if names is None:  # simple value lookup
# --> 310             return cls.__new__(cls, value)
#     311         # otherwise, functional API: we're creating a new Enum type
#     312         return cls._create_(value, names, module=module, qualname=qualname, type=type, start=start)
#
# KeyboardInterrupt:

# %% [markdown]
# # 2. Aggregate by Day

# %%
test = test['2017-08-25 00:00:00':]
test_D = test.resample('D').sum()

# %%
for col in tqdm(test_D.columns):
    df = pd.DataFrame({
        'ds': test_D.index,
        'y': test_D[col],
    })

    ## Set model setting 
    m = Prophet(
        growth='linear', 
        changepoint_range=0.95,
        changepoint_prior_scale=0.1,
        yearly_seasonality=True
    )
    m.fit(df)
    
    ## Make dataframe for get a predicted value
    future = m.make_future_dataframe(periods=10)
    
    ## Predict
    forecast = m.predict(future)
    for i in range(10):
        submission.loc[col, 'X2018_7_' + str(i + 1) + '_d'] = forecast.loc[len(df) + i, 'yhat']
        
#     ## Show a graph
#     fig1 = m.plot(forecast)
#     plt.show()
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#   0%|          | 1/200 [00:01<05:15,  1.59s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#   1%|          | 2/200 [00:03<05:05,  1.54s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#   2%|▏         | 3/200 [00:04<04:57,  1.51s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#   2%|▏         | 4/200 [00:05<04:51,  1.49s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#   2%|▎         | 5/200 [00:07<04:44,  1.46s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#   3%|▎         | 6/200 [00:08<04:49,  1.49s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#   4%|▎         | 7/200 [00:10<04:45,  1.48s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#   4%|▍         | 8/200 [00:11<04:42,  1.47s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#   4%|▍         | 9/200 [00:13<04:40,  1.47s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#   5%|▌         | 10/200 [00:14<04:34,  1.44s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#   6%|▌         | 11/200 [00:16<04:32,  1.44s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#   6%|▌         | 12/200 [00:17<04:34,  1.46s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#   6%|▋         | 13/200 [00:18<04:30,  1.45s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#   7%|▋         | 14/200 [00:20<04:28,  1.44s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#   8%|▊         | 15/200 [00:21<04:25,  1.44s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#   8%|▊         | 16/200 [00:23<04:25,  1.44s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#   8%|▊         | 17/200 [00:24<04:21,  1.43s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#   9%|▉         | 18/200 [00:26<04:23,  1.45s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  10%|▉         | 19/200 [00:27<04:21,  1.44s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  10%|█         | 20/200 [00:29<04:21,  1.45s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  10%|█         | 21/200 [00:30<04:20,  1.46s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  11%|█         | 22/200 [00:32<04:20,  1.46s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  12%|█▏        | 23/200 [00:33<04:17,  1.46s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  12%|█▏        | 24/200 [00:34<04:17,  1.46s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  12%|█▎        | 25/200 [00:36<04:12,  1.44s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  13%|█▎        | 26/200 [00:37<04:09,  1.43s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  14%|█▎        | 27/200 [00:39<04:07,  1.43s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  14%|█▍        | 28/200 [00:40<04:06,  1.43s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  14%|█▍        | 29/200 [00:42<04:11,  1.47s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  15%|█▌        | 30/200 [00:43<04:07,  1.46s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  16%|█▌        | 31/200 [00:45<04:04,  1.45s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  16%|█▌        | 32/200 [00:46<04:00,  1.43s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  16%|█▋        | 33/200 [00:47<04:01,  1.45s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  17%|█▋        | 34/200 [00:49<04:02,  1.46s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  18%|█▊        | 35/200 [00:50<04:02,  1.47s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  18%|█▊        | 36/200 [00:52<03:58,  1.45s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  18%|█▊        | 37/200 [00:53<03:55,  1.44s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  19%|█▉        | 38/200 [00:55<03:51,  1.43s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  20%|█▉        | 39/200 [00:56<03:50,  1.43s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  20%|██        | 40/200 [00:57<03:48,  1.43s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#
41s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  81%|████████  | 162/200 [03:54<00:53,  1.41s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  82%|████████▏ | 163/200 [03:55<00:52,  1.41s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  82%|████████▏ | 164/200 [03:57<00:51,  1.43s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  82%|████████▎ | 165/200 [03:58<00:49,  1.42s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  83%|████████▎ | 166/200 [03:59<00:48,  1.42s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  84%|████████▎ | 167/200 [04:01<00:47,  1.43s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  84%|████████▍ | 168/200 [04:02<00:45,  1.42s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  84%|████████▍ | 169/200 [04:04<00:45,  1.46s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  85%|████████▌ | 170/200 [04:05<00:43,  1.44s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  86%|████████▌ | 171/200 [04:07<00:41,  1.43s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  86%|████████▌ | 172/200 [04:08<00:39,  1.42s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  86%|████████▋ | 173/200 [04:09<00:38,  1.43s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  87%|████████▋ | 174/200 [04:11<00:37,  1.43s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  88%|████████▊ | 175/200 [04:12<00:36,  1.45s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  88%|████████▊ | 176/200 [04:14<00:34,  1.45s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  88%|████████▊ | 177/200 [04:15<00:32,  1.43s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  89%|████████▉ | 178/200 [04:17<00:31,  1.42s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  90%|████████▉ | 179/200 [04:18<00:29,  1.41s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  90%|█████████ | 180/200 [04:19<00:28,  1.40s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  90%|█████████ | 181/200 [04:21<00:27,  1.42s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  91%|█████████ | 182/200 [04:22<00:25,  1.43s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  92%|█████████▏| 183/200 [04:24<00:24,  1.44s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  92%|█████████▏| 184/200 [04:25<00:22,  1.43s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  92%|█████████▎| 185/200 [04:27<00:21,  1.42s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  93%|█████████▎| 186/200 [04:28<00:19,  1.42s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  94%|█████████▎| 187/200 [04:30<00:18,  1.44s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  94%|█████████▍| 188/200 [04:31<00:17,  1.44s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  94%|█████████▍| 189/200 [04:32<00:15,  1.45s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  95%|█████████▌| 190/200 [04:34<00:14,  1.45s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  96%|█████████▌| 191/200 [04:35<00:12,  1.44s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  96%|█████████▌| 192/200 [04:37<00:11,  1.43s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  96%|█████████▋| 193/200 [04:38<00:10,  1.44s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  97%|█████████▋| 194/200 [04:40<00:08,  1.43s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  98%|█████████▊| 195/200 [04:41<00:07,  1.44s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  98%|█████████▊| 196/200 [04:42<00:05,  1.42s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  98%|█████████▊| 197/200 [04:44<00:04,  1.43s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
#  99%|█████████▉| 198/200 [04:45<00:02,  1.41s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
# 100%|█████████▉| 199/200 [04:47<00:01,  1.44s/it]INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#
#
#
#
#
#
# 100%|██████████| 200/200 [04:48<00:00,  1.42s/it]

# %% [markdown]
# # Aggregate by M

# %%
test = test['2017-08-25 00:00:00':]
test_M = test.resample('M').sum()

# %%
for col in tqdm(test.columns):
    df = pd.DataFrame({
        'ds': test_M.index,
        'y': test_M[col],
    })

    ## Set model setting 
    m = Prophet(
        growth='linear', 
        changepoint_range=0.8,
        changepoint_prior_scale=0.5,
    )
    m.fit(df)
    
    ## Make dataframe for get a predicted value
    future = m.make_future_dataframe(periods=5, freq='M')
    
    ## Predict
    forecast = m.predict(future)
    for i in range(5):
        submission.loc[col, 'X2018_' + str(i + 7) + '_m'] = forecast.loc[len(df) + i, 'yhat']
    
#     ## Show a graph
#     fig1 = m.plot(forecast)
#     plt.show()
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations.Using 7.
#
#
#
#
#
#
#
#   0%|          | 1/200 [00:01<06:04,  1.83s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations.Using 7.
#
#
#
#
#
#
#
#   1%|          | 2/200 [00:03<06:01,  1.82s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations.Using 7.
#
#
#
#
#
#
#
#   2%|▏         | 3/200 [00:05<06:00,  1.83s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations.Using 7.
#
#
#
#
#
#
#
#   2%|▏         | 4/200 [00:07<05:59,  1.83s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations.Using 7.
#
#
#
#
#
#
#
#   2%|▎         | 5/200 [00:09<05:57,  1.84s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations.Using 7.
#
#
#
#
#
#
#
#
/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations.Using 7.
#
#
#
#
#
#
#
#  92%|█████████▏| 183/200 [05:33<00:30,  1.81s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations.Using 7.
#
#
#
#
#
#
#
#  92%|█████████▏| 184/200 [05:35<00:28,  1.81s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations.Using 7.
#
#
#
#
#
#
#
#  92%|█████████▎| 185/200 [05:37<00:27,  1.81s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations.Using 7.
#
#
#
#
#
#
#
#  93%|█████████▎| 186/200 [05:38<00:25,  1.81s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations.Using 7.
#
#
#
#
#
#
#
#  94%|█████████▎| 187/200 [05:40<00:23,  1.81s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations.Using 7.
#
#
#
#
#
#
#
#  94%|█████████▍| 188/200 [05:42<00:21,  1.80s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations.Using 7.
#
#
#
#
#
#
#
#  94%|█████████▍| 189/200 [05:44<00:19,  1.80s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations.Using 7.
#
#
#
#
#
#
#
#  95%|█████████▌| 190/200 [05:46<00:17,  1.80s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations.Using 7.
#
#
#
#
#
#
#
#  96%|█████████▌| 191/200 [05:47<00:16,  1.80s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations.Using 7.
#
#
#
#
#
#
#
#  96%|█████████▌| 192/200 [05:49<00:14,  1.80s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations.Using 7.
#
#
#
#
#
#
#
#  96%|█████████▋| 193/200 [05:51<00:12,  1.80s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations.Using 7.
#
#
#
#
#
#
#
#  97%|█████████▋| 194/200 [05:53<00:10,  1.79s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations.Using 7.
#
#
#
#
#
#
#
#  98%|█████████▊| 195/200 [05:55<00:08,  1.80s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations.Using 7.
#
#
#
#
#
#
#
#  98%|█████████▊| 196/200 [05:56<00:07,  1.81s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations.Using 7.
#
#
#
#
#
#
#
#  98%|█████████▊| 197/200 [05:58<00:05,  1.81s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations.Using 7.
#
#
#
#
#
#
#
#  99%|█████████▉| 198/200 [06:00<00:03,  1.80s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations.Using 7.
#
#
#
#
#
#
#
# 100%|█████████▉| 199/200 [06:02<00:01,  1.81s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations.Using 7.
#
#
#
#
#
#
#
# 100%|██████████| 200/200 [06:04<00:00,  1.81s/it]

# %%
# test = to_panel_format(test) # 데이터 형식 변겅
# agg = prediction(test) # 예측

# output1 = pd.concat(agg, ignore_index=False)
# output2 = output1.reset_index().drop(['level_0','level_1'], axis=1)
# output2['id'] = output2['meter_id'].str.replace('X','').astype(int)
# output2 =  output2.sort_values(by='id', ascending=True).drop(['id'], axis=1).reset_index(drop=True)
# output2.to_csv('sub_baseline.csv', index=False)

# %%
submission.to_csv('sub_fbprophet.csv', index=False)

# %%
submission.columns
# Out:
# Index(['X2018_7_1_d', 'X2018_7_2_d', 'X2018_7_3_d', 'X2018_7_4_d',
#        'X2018_7_5_d', 'X2018_7_6_d', 'X2018_7_7_d', 'X2018_7_8_d',
#        'X2018_7_9_d', 'X2018_7_10_d', 'X2018_7_m', 'X2018_8_m', 'X2018_9_m',
#        'X2018_10_m', 'X2018_11_m', 'X2017_7_1_1_h', 'X2017_7_1_2_h',
#        'X2017_7_1_3_h', 'X2017_7_1_4_h', 'X2017_7_1_5_h', 'X2017_7_1_6_h',
#        'X2017_7_1_7_h', 'X2017_7_1_8_h', 'X2017_7_1_9_h', 'X2017_7_1_10_h',
#        'X2017_7_1_11_h', 'X2017_7_1_12_h', 'X2017_7_1_13_h', 'X2017_7_1_14_h',
#        'X2017_7_1_15_h', 'X2017_7_1_16_h', 'X2017_7_1_17_h', 'X2017_7_1_18_h',
#        'X2017_7_1_19_h', 'X2017_7_1_20_h', 'X2017_7_1_21_h', 'X2017_7_1_22_h',
#        'X2017_7_1_23_h', 'X2017_7_1_24_h'],
#       dtype='object')

# %%
submission = submission[['X2017_7_1_3_h', 'X2017_7_1_4_h', 'X2017_7_1_5_h', 'X2017_7_1_6_h',
       'X2017_7_1_7_h', 'X2017_7_1_8_h', 'X2017_7_1_9_h', 'X2017_7_1_10_h',
       'X2017_7_1_11_h', 'X2017_7_1_12_h', 'X2017_7_1_13_h', 'X2017_7_1_14_h',
       'X2017_7_1_15_h', 'X2017_7_1_16_h', 'X2017_7_1_17_h', 'X2017_7_1_18_h',
       'X2017_7_1_19_h', 'X2017_7_1_20_h', 'X2017_7_1_21_h', 'X2017_7_1_22_h',
       'X2017_7_1_23_h', 'X2017_7_1_24_h','X2018_7_1_d', 'X2018_7_2_d', 'X2018_7_3_d', 'X2018_7_4_d',
       'X2018_7_5_d', 'X2018_7_6_d', 'X2018_7_7_d', 'X2018_7_8_d',
       'X2018_7_9_d', 'X2018_7_10_d', 'X2018_7_m', 'X2018_8_m', 'X2018_9_m',
       'X2018_10_m', 'X2018_11_m']]

# %%
submission.reset_index().to_csv('sub_fbprophet.csv', index=False)

# %%
submission.head()
# Out:
#           X2017_7_1_3_h  X2017_7_1_4_h  X2017_7_1_5_h  X2017_7_1_6_h  \
# meter_id
# X5             5.871975       5.811969       5.818463       5.517748
# X7             1.061695       1.108602       1.138722       1.097731
# X10            2.141522       2.287132       2.144392       2.176251
# X16            3.275182       3.279879       3.243610       3.362064
# X18            2.522369       2.517183       2.532031       2.554119
#
#           X2017_7_1_7_h  X2017_7_1_8_h  X2017_7_1_9_h  X2017_7_1_10_h  \
# meter_id
# X5             5.653051       6.294713       5.929817        6.191925
# X7             1.036900       1.833626       2.268283        1.951154
# X10            2.184234       4.515943       6.490085        5.513988
# X16            3.394243       3.529407       4.138677        5.165331
# X18            2.855331       2.691895       2.608116        2.562211
#
#           X2017_7_1_11_h  X2017_7_1_12_h  ...  X2018_7_6_d  X2018_7_7_d  \
# meter_id                                  ...
# X5              6.000700        6.118113  ...   175.723503   177.448347
# X7              2.243338        2.875763  ...    62.958806    65.360642
# X10             5.737400        6.243219  ...   119.500375   124.355357
# X16             5.804338        6.195723  ...   135.261440   138.446513
# X18             2.560741        2.581363  ...    72.976400    73.759734
#
#           X2018_7_8_d  X2018_7_9_d  X2018_7_10_d    X2018_7_m    X2018_8_m  \
# meter_id
# X5         178.650011   178.743675    179.205640  6200.833349  7700.958922
# X7          66.756898    66.093701     66.188261  1530.310469  1905.917707
# X10        126.658505   116.424292    122.164499  3434.998308  4279.366037
# X16        139.581565   137.489556    138.140799  4375.166168  5461.187042
# X18         74.333166    74.286132     74.447586  2650.993820  3266.448779
#
#             X2018_9_m    X2018_10_m    X2018_11_m
# meter_id
# X5        9152.693346  10652.818918  12104.553343
# X7        2269.408582   2645.015820   3008.506695
# X10       5096.496098   5940.863828   6757.993889
# X16       6512.174985   7598.195859   8649.183802
# X18       3862.050351   4477.505310   5073.106883
#
# [5 rows x 37 columns]

# %%
submission.reset_index()
# Out:
#     meter_id  X2017_7_1_3_h  X2017_7_1_4_h  X2017_7_1_5_h  X2017_7_1_6_h  \
# 0         X5       5.871975       5.811969       5.818463       5.517748
# 1         X7       1.061695       1.108602       1.138722       1.097731
# 2        X10       2.141522       2.287132       2.144392       2.176251
# 3        X16       3.275182       3.279879       3.243610       3.362064
# 4        X18       2.522369       2.517183       2.532031       2.554119
